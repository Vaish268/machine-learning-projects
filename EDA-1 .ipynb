# %% [markdown]
# # Exploratory Data Analysis on a Dataset
# Objective:
# The main goal of this assignment is to conduct a thorough exploratory analysis of the "cardiographic.csv" dataset to uncover insights, identify patterns, and understand the dataset's underlying structure. You will use statistical summaries, visualizations, and data manipulation techniques to explore the dataset comprehensively.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Cardiotocographic.csv')
data.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
missing_values = data.isnull().sum()
missing_values
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
data_types = data.dtypes
data_types
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
# Impute missing values with the median of each column
data = data.fillna(data.median())

# %%
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
# Verify that there are no more missing values
missing_values_after_imputation = data.isnull().sum()
missing_values_after_imputation
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
# Set the style of the visualization
sns.set(style="whitegrid")

# Plot box plots for each numerical variable
plt.figure(figsize=(20, 15))
for i, column in enumerate(data.columns):
    plt.subplot(4, 4, i+1)
    sns.boxplot(data[column])
    plt.title(column)
    plt.tight_layout()

plt.show()
# Out:
# /var/folders/5k/r3l31pv16w7dpzj4651hl7zw0000gn/T/ipykernel_3846/3026111929.py:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /var/folders/5k/r3l31pv16w7dpzj4651hl7zw0000gn/T/ipykernel_3846/3026111929.py:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /var/folders/5k/r3l31pv16w7dpzj4651hl7zw0000gn/T/ipykernel_3846/3026111929.py:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /var/folders/5k/r3l31pv16w7dpzj4651hl7zw0000gn/T/ipykernel_3846/3026111929.py:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /var/folders/5k/r3l31pv16w7dpzj4651hl7zw0000gn/T/ipykernel_3846/3026111929.py:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# /var/folders/5k/r3l31pv16w7dpzj4651hl7zw0000gn/T/ipykernel_3846/3026111929.py:10: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# ...

# %%
# Statistical summary for each variable
summary_stats = data.describe().T
summary_stats
# Out:
#            count        mean        std         min         25%         50%  \
# LB        2126.0  133.340204  11.214379   51.842487  126.000000  133.000000
# AC        2126.0    0.003204   0.004373   -0.019284    0.000000    0.001634
# FM        2126.0    0.009894   0.067540   -0.480634    0.000000    0.000000
# UC        2126.0    0.004391   0.003340   -0.014925    0.001851    0.004484
# DL        2126.0    0.001895   0.003343   -0.015393    0.000000    0.000000
# DS        2126.0    0.000002   0.000141   -0.001353    0.000000    0.000000
# DP        2126.0    0.000173   0.000836   -0.005348    0.000000    0.000000
# ASTV      2126.0   46.995984  18.813973  -63.000000   32.000000   49.000000
# MSTV      2126.0    1.364378   1.173632   -6.600000    0.700000    1.200000
# ALTV      2126.0   10.285964  21.205041  -91.000000    0.000000    0.000000
# MLTV      2126.0    8.276147   7.734851  -50.700000    4.600000    7.400000
# ...

# %%
# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Conclusion

# Summarize key insights from the exploratory data analysis
conclusion_text = """
### Conclusion

1. **Baseline Fetal Heart Rate (FHR)**:
   - The median FHR (LB) is around [median_LB].
   - There are some outliers in the FHR data which could indicate unusual fetal conditions.

2. **Accelerations (AC) and Fetal Movements (FM)**:
   - The majority of the data points for AC and FM are close to zero, indicating rare occurrences of accelerations and fetal movements in the recorded data.
   - Further investigation is required to understand the clinical implications of these low values.

3. **Uterine Contractions (UC) and Decelerations (DL, DS, DP)**:
   - UC values show a range of variations, and the presence of outliers suggests occasional high-intensity contractions.
   - Decelerations (late, short, prolonged) have very low median values, indicating fewer instances of decelerations. However, outliers suggest episodes of fetal distress.

4. **Variability Measures (ASTV, MSTV, ALTV, MLTV)**:
   - The variability measures such as ASTV, MSTV, ALTV, and MLTV show interesting patterns that could be indicative of fetal well-being.
   - ASTV and ALTV have higher median values, indicating more time with abnormal variability.
   - MSTV and MLTV show a broader range of values, suggesting varying degrees of short-term and long-term variability in FHR.

5. **Correlation Insights**:
   - There are significant correlations between certain variables. For instance, a high correlation between UC and DL suggests that uterine contractions are often associated with late decelerations.
   - The correlation heatmap reveals interesting relationships that could be explored further for clinical significance.

### Recommendations for Further Analysis:
- Investigate the clinical significance of outliers in the dataset.
- Perform time-series analysis if temporal data is available to understand trends over time.
- Explore potential causative factors for high variability and decelerations in FHR.

### Impact on Decision-Making:
- The insights gained from this analysis can aid in early detection of fetal distress and improve monitoring protocols during pregnancy.
- Further analysis and validation with clinical outcomes could enhance the predictive capabilities of these measurements, leading to better fetal health management.
"""

print(conclusion_text)
# Out:
# ### Conclusion
#
# 1. **Baseline Fetal Heart Rate (FHR)**:
#    - The median FHR (LB) is around [median_LB].
#    - There are some outliers in the FHR data which could indicate unusual fetal conditions.
#
# 2. **Accelerations (AC) and Fetal Movements (FM)**:
#    - The majority of the data points for AC and FM are close to zero, indicating rare occurrences of accelerations and fetal movements in the recorded data.
#    - Further investigation is required to understand the clinical implications of these low values.
#
# 3. **Uterine Contractions (UC) and Decelerations (DL, DS, DP)**:
#    - UC values show a range of variations, and the presence of outliers suggests occasional high-intensity contractions.
#    - Decelerations (late, short, prolonged) have very low median values, indicating fewer instances of decelerations. However, outliers suggest episodes of fetal distress.
#
# 4. **Variability Measures (ASTV, MSTV, ALTV, MLTV)**:
# ...
