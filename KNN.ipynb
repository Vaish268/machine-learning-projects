# %% [markdown]
# # Objective
#
# The objective of this assignment is to implement and evaluate the K-Nearest Neighbours algorithm for classification using the given datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 100
plt.rcParams['font.size'] = 12
sns.set_theme(style='darkgrid', palette='rainbow')
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('Zoo.csv')
df
# Out:
#     animal name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0      aardvark     1         0     0     1         0        0         1
# 1      antelope     1         0     0     1         0        0         0
# 2          bass     0         0     1     0         0        1         1
# 3          bear     1         0     0     1         0        0         1
# 4          boar     1         0     0     1         0        0         1
# ..          ...   ...       ...   ...   ...       ...      ...       ...
# 96      wallaby     1         0     0     1         0        0         0
# 97         wasp     1         0     1     0         1        0         0
# 98         wolf     1         0     0     1         0        0         1
# 99         worm     0         0     1     0         0        0         0
# 100        wren     0         1     1     0         1        0         0
#
#      toothed  backbone  breathes  venomous  fins  legs  tail  domestic  \
# 0          1         1         1         0     0     4     0         0
# 1          1         1         1         0     0     4     1         0
# 2          1         1         0         0     1     0     1         0
# 3          1         1         1         0     0     4     0         0
# 4          1         1         1         0     0     4     1         0
# ..       ...       ...       ...       ...   ...   ...   ...       ...
# 96         1         1         1         0     0     2     1         0
# 97         0         0         1         1     0     6     0         0
# 98         1         1         1         0     0     4     1         0
# 99         0         0         1         0     0     0     0         0
# 100        0         1         1         0     0     2     1         0
#
#      catsize  type
# 0          1     1
# 1          1     1
# 2          0     4
# 3          1     1
# 4          1     1
# ..       ...   ...
# 96         1     1
# 97         0     6
# 98         1     1
# 99         0     7
# 100        0     2
#
# [101 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   animal name  101 non-null    object
#  1   hair         101 non-null    int64
#  2   feathers     101 non-null    int64
#  3   eggs         101 non-null    int64
#  4   milk         101 non-null    int64
#  5   airborne     101 non-null    int64
#  6   aquatic      101 non-null    int64
#  7   predator     101 non-null    int64
#  8   toothed      101 non-null    int64
#  9   backbone     101 non-null    int64
#  10  breathes     101 non-null    int64
#  11  venomous     101 non-null    int64
#  12  fins         101 non-null    int64
#  13  legs         101 non-null    int64
#  14  tail         101 non-null    int64
#  15  domestic     101 non-null    int64
#  16  catsize      101 non-null    int64
#  17  type         101 non-null    int64
# dtypes: int64(17), object(1)
# memory usage: 14.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#              hair    feathers        eggs        milk    airborne     aquatic  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.425743    0.198020    0.584158    0.405941    0.237624    0.356436
# std      0.496921    0.400495    0.495325    0.493522    0.427750    0.481335
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 75%      1.000000    0.000000    1.000000    1.000000    0.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          predator     toothed    backbone    breathes    venomous        fins  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.554455    0.603960    0.821782    0.792079    0.079208    0.168317
# std      0.499505    0.491512    0.384605    0.407844    0.271410    0.376013
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    1.000000    1.000000    0.000000    0.000000
# 50%      1.000000    1.000000    1.000000    1.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#              legs        tail    domestic     catsize        type
# count  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     2.841584    0.742574    0.128713    0.435644    2.831683
# std      2.033385    0.439397    0.336552    0.498314    2.102709
# min      0.000000    0.000000    0.000000    0.000000    1.000000
# 25%      2.000000    0.000000    0.000000    0.000000    1.000000
# 50%      4.000000    1.000000    0.000000    0.000000    2.000000
# 75%      4.000000    1.000000    0.000000    1.000000    4.000000
# max      8.000000    1.000000    1.000000    1.000000    7.000000

# %%
for col in df.columns:
    print(df[col].value_counts())
    print()
# Out:
# frog        2
# pony        1
# sealion     1
# seal        1
# seahorse    1
#            ..
# gorilla     1
# goat        1
# gnat        1
# girl        1
# wren        1
# Name: animal name, Length: 100, dtype: int64
#
# 0    58
# 1    43
# Name: hair, dtype: int64
#
# 0    81
# 1    20
# Name: feathers, dtype: int64
#
# 1    59
# 0    42
# Name: eggs, dtype: int64
#
# 0    60
# 1    41
# Name: milk, dtype: int64
#
# 0    77
# 1    24
# Name: airborne, dtype: int64
#
# 0    65
# 1    36
# Name: aquatic, dtype: int64
#
# 1    56
# 0    45
# Name: predator, dtype: int64
#
# 1    61
# 0    40
# Name: toothed, dtype: int64
#
# 1    83
# 0    18
# Name: backbone, dtype: int64
#
# 1    80
# 0    21
# Name: breathes, dtype: int64
#
# 0    93
# 1     8
# Name: venomous, dtype: int64
#
# 0    84
# 1    17
# Name: fins, dtype: int64
#
# 4    38
# 2    27
# 0    23
# 6    10
# 8     2
# 5     1
# Name: legs, dtype: int64
#
# 1    75
# 0    26
# Name: tail, dtype: int64
#
# 0    88
# 1    13
# Name: domestic, dtype: int64
#
# 0    57
# 1    44
# Name: catsize, dtype: int64
#
# 1    41
# 2    20
# 4    13
# 7    10
# 6     8
# 3     5
# 5     4
# Name: type, dtype: int64

# %%
#histogram
df.hist(bins=10, figsize=(20,15))
plt.show()

# %%
#correleation
df.drop(columns = ["animal name"]).corr()
# Out:
#               hair  feathers      eggs      milk  airborne   aquatic  \
# hair      1.000000 -0.427851 -0.817382  0.878503 -0.198431 -0.473554
# feathers -0.427851  1.000000  0.419248 -0.410761  0.656553 -0.058552
# eggs     -0.817382  0.419248  1.000000 -0.938848  0.376646  0.376244
# milk      0.878503 -0.410761 -0.938848  1.000000 -0.366765 -0.362613
# airborne -0.198431  0.656553  0.376646 -0.366765  1.000000 -0.172638
# aquatic  -0.473554 -0.058552  0.376244 -0.362613 -0.172638  1.000000
# predator -0.154769 -0.104430  0.011605 -0.029721 -0.295181  0.375978
# toothed   0.492531 -0.613631 -0.642150  0.628168 -0.594311  0.053150
# backbone  0.191681  0.231403 -0.340420  0.384958 -0.104718  0.022463
# breathes  0.441149  0.254588 -0.382777  0.423527  0.286039 -0.637506
# venomous -0.104245 -0.145739  0.098689 -0.242449  0.008528  0.087915
# fins     -0.280313 -0.223541  0.164796 -0.156328 -0.251157  0.604492
# legs      0.394009 -0.206686 -0.224918  0.214196  0.043712 -0.360638
# tail      0.048973  0.292569 -0.221090  0.210026  0.009482 -0.034642
# domestic  0.207208  0.031586 -0.155610  0.163928  0.063274 -0.224308
# catsize   0.455020 -0.135934 -0.514650  0.574906 -0.349768 -0.111866
# type     -0.562384 -0.197520  0.661825 -0.723683  0.022677  0.326639
#
#           predator   toothed  backbone  breathes  venomous      fins  \
# hair     -0.154769  0.492531  0.191681  0.441149 -0.104245 -0.280313
col0 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_9f876_row0_col9 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_9f876_row0_col11, #T_9f876_row1_col0, #T_9f876_row3_col6 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_9f876_row0_col12 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_9f876_row0_col13 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_9f876_row0_col14, #T_9f876_row4_col8 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_9f876_row0_col15 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_9f876_row0_col16, #T_9f876_row7_col10 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_9f876_row1_col2, #T_9f876_row9_col3, #T_9f876_row15_col0 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_9f876_row1_col3, #T_9f876_row12_col7 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_9f876_row1_col4 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_9f876_row1_col5, #T_9f876_row10_col7, #T_9f876_row14_col16 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_9f876_row1_col6 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_9f876_row1_col7, #T_9f876_row11_col9 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_9f876_row1_col8, #T_9f876_row13_col7 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_9f876_row1_col9 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_9f876_row1_col10 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_9f876_row1_col11, #T_9f876_row2_col6 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_9f876_row1_col13, #T_9f876_row7_col15, #T_9f876_row9_col8, #T_9f876_row11_col2, #T_9f876_row11_col8, #T_9f876_row14_col3 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_9f876_row1_col14, #T_9f876_row16_col1 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_9f876_row1_col15, #T_9f876_row2_col13, #T_9f876_row12_col1, #T_9f876_row13_col6, #T_9f876_row14_col5, #T_9f876_row15_col14 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_9f876_row1_col16, #T_9f876_row5_col1, #T_9f876_row15_col6 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_9f876_row2_col0, #T_9f876_row2_col3, #T_9f876_row2_col7, #T_9f876_row3_col2, #T_9f876_row3_col10, #T_9f876_row5_col9, #T_9f876_row6_col14, #T_9f876_row7_col1, #T_9f876_row7_col4, #T_9f876_row8_col10, #T_9f876_row8_col16, #T_9f876_row9_col5, #T_9f876_row9_col11, #T_9f876_row11_col12, #T_9f876_row14_col6, #T_9f876_row16_col8, #T_9f876_row16_col13, #T_9f876_row16_col15 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9f876_row2_col1 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_9f876_row2_col4, #T_9f876_row7_col11, #T_9f876_row9_col12 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_9f876_row2_col5, #T_9f876_row6_col5 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_9f876_row2_col8, #T_9f876_row5_col10, #T_9f876_row5_col15 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_9f876_row2_col9, #T_9f876_row5_col12, #T_9f876_row7_col2, #T_9f876_row15_col4 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_9f876_row2_col10, #T_9f876_row8_col6 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_9f876_row2_col11, #T_9f876_row6_col8 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_9f876_row2_col12 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_9f876_row2_col15, #T_9f876_row12_col11 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_9f876_row2_col16 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_9f876_row3_col0 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_9f876_row3_col1 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_9f876_row3_col4 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_9f876_row3_col5, #T_9f876_row11_col14 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_9f876_row3_col7 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_9f876_row3_col8 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_9f876_row3_col9, #T_9f876_row15_col8 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_9f876_row3_col11, #T_9f876_row4_col5, #T_9f876_row4_col14, #T_9f876_row16_col6 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_9f876_row3_col12, #T_9f876_row8_col11, #T_9f876_row13_col11, #T_9f876_row14_col8 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_9f876_row3_col13, #T_9f876_row8_col9 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_9f876_row3_col14, #T_9f876_row10_col11 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_9f876_row3_col15, #T_9f876_row7_col0 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_9f876_row3_col16 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_9f876_row4_col0 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_9f876_row4_col1 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_9f876_row4_col2, #T_9f876_row5_col2 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_9f876_row4_col3, #T_9f876_row11_col0, #T_9f876_row15_col1 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_9f876_row4_col6 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_9f876_row4_col7 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_9f876_row4_col9, #T_9f876_row14_col0 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_9f876_row4_col10 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_9f876_row4_col11 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_9f876_row4_col12, #T_9f876_row8_col5, #T_9f876_row11_col3, #T_9f876_row14_col2 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_9f876_row4_col13, #T_9f876_row10_col0, #T_9f876_row10_col12 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_9f876_row4_col15, #T_9f876_row16_col3 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_9f876_row4_col16, #T_9f876_row5_col8, #T_9f876_row14_col9 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_9f876_row5_col0, #T_9f876_row6_col4 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_9f876_row5_col3 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_9f876_row5_col4 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_9f876_row5_col6, #T_9f876_row8_col1, #T_9f876_row12_col16 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_9f876_row5_col7, #T_9f876_row14_col12 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_9f876_row5_col11 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_9f876_row5_col13, #T_9f876_row6_col0, #T_9f876_row11_col15 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_9f876_row5_col16, #T_9f876_row10_col16 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_9f876_row6_col1, #T_9f876_row6_col12, #T_9f876_row8_col14, #T_9f876_row10_col9 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_9f876_row6_col2 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_9f876_row6_col3, #T_9f876_row6_col7 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_9f876_row6_col9 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_9f876_row6_col10, #T_9f876_row7_col14, #T_9f876_row10_col1, #T_9f876_row12_col14 {
#   background-

# %%
#train test split
X = df.drop(columns = ["animal name", "type"])
y = df["type"]
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=108)

print("Shapes")
print("X_train :", X_train.shape)
print("X_test  :", X_test.shape)
print("y_train :", y_train.shape)
print("y_test  :", y_test.shape)
# Out:
# Shapes
# X_train : (80, 16)
# X_test  : (21, 16)
# y_train : (80,)
# y_test  : (21,)

# %%
#KNN classifier model
knn = KNeighborsClassifier(n_neighbors = 3,weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski', metric_params=None, n_jobs=None)
knn.fit(X_train,y_train)
ypred = knn.predict(X_test)

print("Training Accuracy", knn.score(X_train,y_train))
print("Testing Accuracy", knn.score(X_test,y_test))
print()
print(classification_report(y_test,ypred))
# Out:
# Training Accuracy 0.975
# Testing Accuracy 1.0
#
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         8
#            2       1.00      1.00      1.00         6
#            4       1.00      1.00      1.00         4
#            7       1.00      1.00      1.00         3
#
#     accuracy                           1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21

# %% [markdown]
# #  hyperparameter tuning for knn

# %%
#grid search cv
from sklearn.model_selection import GridSearchCV

grid_params = { 'n_neighbors' : [5,7,9,11,13,15],
               'weights' : ['uniform','distance'],
               'metric' : ['minkowski','euclidean','manhattan'],
                'algorithm' : ['auto', 'ball_tree', 'kd_tree', 'brute'],
                'leaf_size' :[10,20,30,40],
                'p':[1,2,3,4],
                }

gs = GridSearchCV(KNeighborsClassifier(), grid_params, verbose = 1, cv=3, n_jobs = -1)

# %%
g_res = gs.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 2304 candidates, totalling 6912 fits

# %%
g_res.best_score_
# Out:
# 0.9249762583095916

# %%
g_res.best_params_
# Out:
# {'algorithm': 'ball_tree',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'n_neighbors': 5,
#  'p': 1,
#  'weights': 'distance'}

# %%
#finial
knn = KNeighborsClassifier(n_neighbors = 5, weights = 'distance',algorithm = 'ball_tree',metric = 'minkowski',p=1, leaf_size=30 )
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='ball_tree', p=1, weights='distance')

# %%
ypred = knn.predict(X_test)

print("Training Accuracy", knn.score(X_train,y_train))
print("Testing Accuracy", knn.score(X_test,y_test))
print()
print(classification_report(y_test,ypred))
# Out:
# Training Accuracy 1.0
# Testing Accuracy 1.0
#
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         8
#            2       1.00      1.00      1.00         6
#            4       1.00      1.00      1.00         4
#            7       1.00      1.00      1.00         3
#
#     accuracy                           1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21

# %% [markdown]
# # perform PCA for visualization

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

sc = StandardScaler()
x = sc.fit_transform(X)

pca = PCA()
pcs = pca.fit_transform(x)

# %%
# 2D visualization 
from matplotlib.pyplot import figure

figure(figsize=(18, 6), dpi=160)

pca = PCA(n_components=2)
pcs = pca.fit_transform(x)

data = pd.DataFrame(pcs,columns=['PC1','PC2'])
data['Class'] = y

sns.scatterplot(x = data['PC1'], y = data['PC2'],s = 50, edgecolor = 'black',hue=data['Class'], palette='Set1')
plt.show()
