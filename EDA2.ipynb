# %%
# Data Exploration and Preprocessing

import pandas as pd
data = pd.read_csv('adult_with_headers.csv')
data
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %%
summary_stats = data.describe(include='all')
data_info = data.info()
summary_stats, data_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# (                 age workclass        fnlwgt education  education_num  \
#  count   32561.000000     32561  3.256100e+04     32561   32561.000000
#  unique           NaN         9           NaN        16            NaN
#  top              NaN   Private           NaN   HS-grad            NaN
#  freq             NaN     22696           NaN     10501            NaN
#  mean       38.581647       NaN  1.897784e+05       NaN      10.080679
#  std        13.640433       NaN  1.055500e+05       NaN       2.572720
#  min        17.000000       NaN  1.228500e+04       NaN       1.000000
#  25%        28.000000       NaN  1.178270e+05       NaN       9.000000
#  50%        37.000000       NaN  1.783560e+05       NaN      10.000000
#  75%        48.000000       NaN  2.370510e+05       NaN      12.000000
#  max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#               marital_status       occupation relationship    race    sex  \
#  count                 32561            32561        32561   32561  32561
#  unique                    7               15            6       5      2
#  top      Married-civ-spouse   Prof-specialty      Husband   White   Male
#  freq                  14976             4140        13193   27816  21790
#  mean                    NaN              NaN          NaN     NaN    NaN
#  std                     NaN              NaN          NaN     NaN    NaN
#  min                     NaN              NaN          NaN     NaN    NaN
#  25%                     NaN              NaN          NaN     NaN    NaN
#  50%                     NaN              NaN          NaN     NaN    NaN
#  75%                     NaN              NaN          NaN     NaN    NaN
#  max                     NaN              NaN          NaN     NaN    NaN
#
#          capital_gain  capital_loss  hours_per_week  native_country  income
#  count   32561.000000  32561.000000    32561.000000           32561   32561
#  unique           NaN           NaN             NaN              42       2
#  top              NaN           NaN             NaN   United-States   <=50K
#  freq             NaN           NaN             NaN           29170   24720
#  mean     1077.648844     87.303830       40.437456             NaN     NaN
#  std      7385.292085    402.960219       12.347429             NaN     NaN
#  min         0.000000      0.000000        1.000000             NaN     NaN
#  25%         0.000000      0.000000       40.000000             NaN     NaN
#  50%         0.000000      0.000000       40.000000             NaN     NaN
#  75%         0.000000      0.000000       45.000000             NaN     NaN
#  max     99999.000000   4356.000000       99.000000             NaN     NaN  ,
#  None)

# %%
print(data.describe(include='all'))
print(data.info())
# Out:
#                  age workclass        fnlwgt education  education_num  \
# count   32561.000000     32561  3.256100e+04     32561   32561.000000
# unique           NaN         9           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581647       NaN  1.897784e+05       NaN      10.080679
# std        13.640433       NaN  1.055500e+05       NaN       2.572720
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#              marital_status       occupation relationship    race    sex  \
# count                 32561            32561        32561   32561  32561
# unique                    7               15            6       5      2
# top      Married-civ-spouse   Prof-specialty      Husband   White   Male
# freq                  14976             4140        13193   27816  21790
# mean                    NaN              NaN          NaN     NaN    NaN
# std                     NaN              NaN          NaN     NaN    NaN
# min                     NaN              NaN          NaN     NaN    NaN
# 25%                     NaN              NaN          NaN     NaN    NaN
# 50%                     NaN              NaN          NaN     NaN    NaN
# 75%                     NaN              NaN          NaN     NaN    NaN
# max                     NaN              NaN          NaN     NaN    NaN
#
#         capital_gain  capital_loss  hours_per_week  native_country  income
# count   32561.000000  32561.000000    32561.000000           32561   32561
# unique           NaN           NaN             NaN              42       2
# top              NaN           NaN             NaN   United-States   <=50K
# freq             NaN           NaN             NaN           29170   24720
# mean     1077.648844     87.303830       40.437456             NaN     NaN
# std      7385.292085    402.960219       12.347429             NaN     NaN
# min         0.000000      0.000000        1.000000             NaN     NaN
# 25%         0.000000      0.000000       40.000000             NaN     NaN
# 50%         0.000000      0.000000       40.000000             NaN     NaN
# 75%         0.000000      0.000000       45.000000             NaN     NaN
# max     99999.000000   4356.000000       99.000000             NaN     NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None

# %%
missing_values = data.isnull().sum()
print(missing_values)

for column in data.columns:
    if data[column].isnull().sum() > 0:
        if data[column].dtype == 'object':
            data[column].fillna(data[column].mode()[0], inplace=True)
        else:
            data[column].fillna(data[column].mean(), inplace=True)
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler_standard = StandardScaler()
data_standard_scaled = data.copy()
data_standard_scaled[data_standard_scaled.select_dtypes(include=['int64', 'float64']).columns] = scaler_standard.fit_transform(data_standard_scaled.select_dtypes(include=['int64', 'float64']))
data_standard_scaled
# Out:
#             age          workclass    fnlwgt    education  education_num  \
# 0      0.030671          State-gov -1.063611    Bachelors       1.134739
# 1      0.837109   Self-emp-not-inc -1.008707    Bachelors       1.134739
# 2     -0.042642            Private  0.245079      HS-grad      -0.420060
# 3      1.057047            Private  0.425801         11th      -1.197459
# 4     -0.775768            Private  1.408176    Bachelors       1.134739
# ...         ...                ...       ...          ...            ...
# 32556 -0.849080            Private  0.639741   Assoc-acdm       0.746039
# 32557  0.103983            Private -0.335433      HS-grad      -0.420060
# 32558  1.423610            Private -0.358777      HS-grad      -0.420060
# 32559 -1.215643            Private  0.110960      HS-grad      -0.420060
# 32560  0.983734       Self-emp-inc  0.929893      HS-grad      -0.420060
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male      0.148453      -0.21666       -0.035429   United-States
# 1         Male     -0.145920      -0.21666       -2.222153   United-States
# 2         Male     -0.145920      -0.21666       -0.035429   United-States
# 3         Male     -0.145920      -0.21666       -0.035429   United-States
# 4       Female     -0.145920      -0.21666       -0.035429            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female     -0.145920      -0.21666       -0.197409   United-States
# 32557     Male     -0.145920      -0.21666       -0.035429   United-States
# 32558   Female     -0.145920      -0.21666       -0.035429   United-States
# 32559     Male     -0.145920      -0.21666       -1.655225   United-States
# 32560   Female      1.888424      -0.21666       -0.035429   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %%
scaler_minmax = MinMaxScaler()
data_minmax_scaled = data.copy()
data_minmax_scaled[data_minmax_scaled.select_dtypes(include=['int64', 'float64']).columns] = scaler_minmax.fit_transform(data_minmax_scaled.select_dtypes(include=['int64', 'float64']))
data_minmax_scaled
# Out:
#             age          workclass    fnlwgt    education  education_num  \
# 0      0.301370          State-gov  0.044302    Bachelors       0.800000
# 1      0.452055   Self-emp-not-inc  0.048238    Bachelors       0.800000
# 2      0.287671            Private  0.138113      HS-grad       0.533333
# 3      0.493151            Private  0.151068         11th       0.400000
# 4      0.150685            Private  0.221488    Bachelors       0.800000
# ...         ...                ...       ...          ...            ...
# 32556  0.136986            Private  0.166404   Assoc-acdm       0.733333
# 32557  0.315068            Private  0.096500      HS-grad       0.533333
# 32558  0.561644            Private  0.094827      HS-grad       0.533333
# 32559  0.068493            Private  0.128499      HS-grad       0.533333
# 32560  0.479452       Self-emp-inc  0.187203      HS-grad       0.533333
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital_gain  capital_loss  hours_per_week  native_country  \
# 0         Male      0.021740           0.0        0.397959   United-States
# 1         Male      0.000000           0.0        0.122449   United-States
# 2         Male      0.000000           0.0        0.397959   United-States
# 3         Male      0.000000           0.0        0.397959   United-States
# 4       Female      0.000000           0.0        0.397959            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female      0.000000           0.0        0.377551   United-States
# 32557     Male      0.000000           0.0        0.397959   United-States
# 32558   Female      0.000000           0.0        0.397959   United-States
# 32559     Male      0.000000           0.0        0.193878   United-States
# 32560   Female      0.150242           0.0        0.397959   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %%
# Encoding Techniques

from sklearn.preprocessing import OneHotEncoder, LabelEncoder
categorical_columns = [col for col in data.select_dtypes(include=['object']).columns if data[col].nunique() < 5]
data_one_hot_encoded = pd.get_dummies(data, columns=categorical_columns)
data_one_hot_encoded
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#        capital_gain  capital_loss  hours_per_week  native_country  \
# 0              2174             0              40   United-States
# 1                 0             0              13   United-States
# 2                 0             0              40   United-States
# 3                 0             0              40   United-States
# 4                 0             0              40            Cuba
# ...             ...           ...             ...             ...
# 32556             0             0              38   United-States
# 32557             0             0              40   United-States
# 32558             0             0              40   United-States
# 32559             0             0              20   United-States
# 32560         15024             0              40   United-States
#
#        sex_ Female  sex_ Male  income_ <=50K  income_ >50K
# 0                0          1              1             0
# 1                0          1              1             0
# 2                0          1              1             0
# 3                0          1              1             0
# 4                1          0              1             0
# ...            ...        ...            ...           ...
# 32556            1          0              1             0
# 32557            0          1              0             1
# 32558            1          0              1             0
# 32559            0          1              1             0
# 32560            1          0              0             1
#
# [32561 rows x 17 columns]

# %%
label_encoder = LabelEncoder()
for col in data.select_dtypes(include=['object']).columns:
    if col not in categorical_columns:
        data[col] = label_encoder.fit_transform(data[col])
label_encoder
# Out:
# LabelEncoder()

# %%
# Example of creating new features
data['hours_per_week_squared'] = data['hours_per_week'] ** 2
data['age_income_ratio'] = data['age'] / (data['capital_gain'] + 1)
data['hours_per_week_squared']
# Out:
# 0        1600
# 1         169
# 2        1600
# 3        1600
# 4        1600
#          ...
# 32556    1444
# 32557    1600
# 32558    1600
# 32559     400
# 32560    1600
# Name: hours_per_week_squared, Length: 32561, dtype: int64

# %%
data['age_income_ratio']
# Out:
# 0         0.017931
# 1        50.000000
# 2        38.000000
# 3        53.000000
# 4        28.000000
#            ...
# 32556    27.000000
# 32557    40.000000
# 32558    58.000000
# 32559    22.000000
# 32560     0.003461
# Name: age_income_ratio, Length: 32561, dtype: float64

# %%
import numpy as np
data['capital_gain'] = np.log1p(data['capital_gain'])
data['capital_gain']
# Out:
# 0        7.684784
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
#            ...
# 32556    0.000000
# 32557    0.000000
# 32558    0.000000
# 32559    0.000000
# 32560    9.617471
# Name: capital_gain, Length: 32561, dtype: float64

# %%
# Feature Selection

from sklearn.ensemble import IsolationForest
iso_forest = IsolationForest(contamination=0.1)
outliers = iso_forest.fit_predict(data.select_dtypes(include=['int64', 'float64']))
data_no_outliers = data[outliers == 1]
iso_forest
# Out:
# IsolationForest(contamination=0.1)

# %%
outliers
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
data_no_outliers
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 5       37          4  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        occupation  relationship  race      sex  capital_gain  capital_loss  \
# 0               1             1     4     Male      7.684784             0
# 1               4             0     4     Male      0.000000             0
# 2               6             1     4     Male      0.000000             0
# 3               6             0     2     Male      0.000000             0
# 5               4             5     4   Female      0.000000             0
# ...           ...           ...   ...      ...           ...           ...
# 32556          13             5     4   Female      0.000000             0
# 32557           7             0     4     Male      0.000000             0
# 32558           1             4     4   Female      0.000000             0
# 32559           1             3     4     Male      0.000000             0
# 32560           4             5     4   Female      9.617471             0
#
#        hours_per_week  native_country  income  hours_per_week_squared  \
# 0                  40              39   <=50K                    1600
# 1                  13              39   <=50K                     169
# 2                  40              39   <=50K                    1600
# 3                  40              39   <=50K                    1600
# 5                  40              39   <=50K                    1600
# ...               ...             ...     ...                     ...
# 32556              38              39   <=50K                    1444
# 32557              40              39    >50K                    1600
# 32558              40              39   <=50K                    1600
# 32559              20              39   <=50K                     400
# 32560              40              39    >50K                    1600
#
#        age_income_ratio
# 0              0.017931
# 1             50.000000
# 2             38.000000
# 3             53.000000
# 5             37.000000
# ...                 ...
# 32556         27.000000
# 32557         40.000000
# 32558         58.000000
# 32559         22.000000
# 32560          0.003461
#
# [29305 rows x 17 columns]

# %%
# Apply PPS (Predictive Power Score):

import ppscore as pps
pps_matrix = pps.matrix(data)
pps_matrix
# Out:
#                     x                       y   ppscore            case  \
# 0                 age                     age  1.000000  predict_itself
# 1                 age               workclass  0.000000      regression
# 2                 age                  fnlwgt  0.000000      regression
# 3                 age               education  0.000000      regression
# 4                 age           education_num  0.000000      regression
# ..                ...                     ...       ...             ...
# 284  age_income_ratio          hours_per_week  0.000000      regression
# 285  age_income_ratio          native_country  0.000000      regression
# 286  age_income_ratio                  income  0.238418  classification
# 287  age_income_ratio  hours_per_week_squared  0.000000      regression
# 288  age_income_ratio        age_income_ratio  1.000000  predict_itself
#
#      is_valid_score               metric  baseline_score   model_score  \
# 0              True                 None        0.000000      1.000000
# 1              True  mean absolute error        0.742600      0.875681
# 2              True  mean absolute error    75872.186200  77535.141544
# 3              True  mean absolute error        2.759000      2.806164
# 4              True  mean absolute error        1.853000      1.898306
# ..              ...                  ...             ...           ...
# 284            True  mean absolute error        7.656400      8.271373
# 285            True  mean absolute error        2.374800      4.245985
# 286            True          weighted F1        0.653115      0.735819
# 287            True  mean absolute error      626.045600    715.025213
# 288            True                 None        0.000000      1.000000
#
#                         model
# 0                        None
# 1     DecisionTreeRegressor()
# 2     DecisionTreeRegressor()
# 3     DecisionTreeRegressor()
# 4     DecisionTreeRegressor()
# ..                        ...
# 284   DecisionTreeRegressor()
# 285   DecisionTreeRegressor()
# 286  DecisionTreeClassifier()
# 287   DecisionTreeRegressor()
# 288                      None
#
# [289 rows x 9 columns]

# %%
correlation_matrix = data.corr()
correlation_matrix
# Out:
# /var/folders/5k/r3l31pv16w7dpzj4651hl7zw0000gn/T/ipykernel_2241/3291346660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()
#                              age  workclass    fnlwgt  education  \
# age                     1.000000   0.003787 -0.076646  -0.010508
# workclass               0.003787   1.000000 -0.016656   0.023513
# fnlwgt                 -0.076646  -0.016656  1.000000  -0.028145
# education              -0.010508   0.023513 -0.028145   1.000000
# education_num           0.036527   0.052085 -0.043195   0.359153
# marital_status         -0.266288  -0.064731  0.028153  -0.038407
# occupation             -0.020947   0.254892  0.001597  -0.021260
# relationship           -0.263698  -0.090461  0.008931  -0.010876
# race                    0.028718   0.049742 -0.021291   0.014131
# capital_gain            0.124183   0.022672 -0.004414   0.024955
# capital_loss            0.057775   0.012216 -0.010252   0.016746
# hours_per_week          0.068756   0.138962 -0.018768   0.055510
# native_country         -0.001151  -0.007690 -0.051966   0.064288
# hours_per_week_squared  0.072882   0.129954 -0.027353   0.045272
# age_income_ratio        0.664370  -0.006390 -0.054557  -0.023016
#
#                         education_num  marital_status  occupation  \
# age                          0.036527       -0.266288   -0.020947
# workclass                    0.052085       -0.064731    0.254892
# fnlwgt                      -0.043195        0.028153    0.001597
# education                    0.359153       -0.038407   -0.021260
# education_num                1.000000       -0.069304    0.109697
# marital_status              -0.069304        1.000000   -0.009654
# occupation                   0.109697       -0.009654    1.000000
# relationship                -0.094153        0.185451   -0.075607
# race                         0.031838       -0.068013    0.006763
# capital_gain                 0.129135       -0.066595    0.019852
# capital_loss                 0.079923       -0.034187    0.017987
# hours_per_week               0.148123       -0.190519    0.080383
# native_country               0.050840       -0.023819   -0.012543
# hours_per_week_squared       0.136576       -0.158243    0.080672
# age_income_ratio            -0.055283       -0.165450   -0.024560
#
#                         relationship      race  capital_gain  capital_loss  \
# age                        -0.263698  0.028718      0.124183      0.057775
# workclass                  -0.090461  0.049742      0.022672      0.012216
# fnlwgt                      0.008931 -0.021291     -0.004414     -0.010252
# education                  -0.010876  0.014131      0.024955      0.016746
# education_num              -0.094153  0.031838      0.129135      0.079923
# marital_status              0.185451 -0.068013     -0.066595     -0.034187
# occupation                 -0.075607  0.006763      0.019852      0.017987
# relationship                1.000000 -0.116055     -0.083402     -0.061062
# race                       -0.116055  1.000000      0.024089      0.018899
# capital_gain               -0.083402  0.024089      1.000000     -0.064840
# capital_loss               -0.061062  0.018899     -0.064840      1.000000
# hours_per_week             -0.248974  0.041910      0.083821      0.054256
# native_country             -0.005507  0.137852      0.005701      0.000419
# hours_per_week_squared     -0.225190  0.047632      0.078828      0.051843
# age_income_ratio           -0.146738  0.002313     -0.624963      0.094651
#
#                         hours_per_week  native_country  \
# age                           0.068756       -0.001151
# workclass                     0.138962       -0.007690
# fnlwgt                       -0.018768       -0.051966
# education                     0.055510        0.064288
# education_num                 0.148123        0.050840
# marital_status               -0.190519       -0.023819
# occupation                    0.080383       -0.012543
# relationship                 -0.248974       -0.005507
# race                          0.041910        0.137852
# capital_gain                  0.083821        0.005701
# capital_loss                  0.054256        0.000419
# hours_per_week                1.000000       -0.002671
# native_country               -0.002671        1.000000
# hours_per_week_squared        0.950920        0.001263
# age_income_ratio              0.007477       -0.004357
#
#                         hours_per_week_squared  age_income_ratio
# age                                   0.072882          0.664370
# workclass                             0.129954         -0.006390
# fnlwgt                               -0.027353         -0.054557
# education                             0.045272         -0.023016
# education_num                         0.136576         -0.055283
# marital_status                       -0.158243         -0.165450
# occupation                            0.080672         -0.024560
# relationship                         -0.225190         -0.146738
# race                                  0.047632          0.002313
# capital_gain                          0.078828         -0.624963
# capital_loss                          0.051843          0.094651
# hours_per_week                        0.950920          0.007477
# native_country                        0.001263         -0.004357
# hours_per_week_squared                1.000000          0.011628
# age_income_ratio                      0.011628          1.000000
